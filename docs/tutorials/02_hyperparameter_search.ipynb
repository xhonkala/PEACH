# %% [markdown]
# WORKFLOW 02: Hyperparameter Search with Cross-Validation
# =========================================================
#
# This workflow demonstrates how to find optimal hyperparameters for archetypal analysis:
# 1. Load preprocessed data (with PCA from WORKFLOW_01)
# 2. Configure search space for hyperparameters
# 3. Run cross-validation grid search
# 4. Analyze results and select best configuration
#
# The hyperparameter search tests combinations of:
# - Number of archetypes (discrete values)
# - Hidden layer dimensions (architecture options)
# - Inflation factor (PCA inflation for Deep AA)
# - CV folds and training settings
#
# Output structure (CVSummary):
# - cv_summary.ranked_configs: List of configs ranked by performance
# - cv_summary.summary_df: DataFrame with all results
# - cv_summary.config_results: Detailed per-config results
#
# Example usage:
#     python WORKFLOW_02.py
#
# Requirements:
#     - peach
#     - scanpy
#     - Data with PCA (from WORKFLOW_01 or equivalent)

# %%
import scanpy as sc
import peach as pc
from pathlib import Path

# %% [markdown]
# ## Configuration

# %%
# Data path - should have PCA already computed
data_path = Path("data/HSC.h5ad")

# Hyperparameter search space
n_archetypes_range = [7, 9, 11]  # Number of archetypes to test
hidden_dims_options = [
    [128, 64],           # Simpler architecture
    [256, 128, 64],      # Deeper architecture
]
inflation_factor_range = [1.0, 1.5]  # PCA inflation factor

# Cross-validation settings
cv_folds = 3                    # Number of CV folds
max_epochs_cv = 50              # Max epochs per fold
early_stopping_patience = 5     # Stop if no improvement
speed_preset = 'fast'           # 'fast', 'balanced', or 'thorough'
subsample_fraction = 0.5        # Use 50% of data for CV
max_cells_cv = 5000             # Maximum cells per CV run
random_state = 42               # For reproducibility

# %% [markdown]
# ## Step 1: Load Data with PCA

# %%
print("Loading data...")
adata = sc.read_h5ad(data_path)
print(f"  Shape: {adata.n_obs:,} cells × {adata.n_vars:,} genes")

# Ensure PCA exists (required for archetypal analysis)
if 'X_pca' not in adata.obsm:
    print("  Running PCA (required for archetypal analysis)...")
    sc.tl.pca(adata, n_comps=13)
    print(f"  PCA computed: {adata.obsm['X_pca'].shape}")
else:
    print(f"  PCA found: {adata.obsm['X_pca'].shape}")

# %% [markdown]
# **NB:** I've found that with archetype analysis you generally get best results when you use a PCA with the smallest n_components with >99% variance explained. The extraneous very low loading PCs just add noise to the archetypal training processes. For many datasets I have gotten best results with 5-11 PCs. Use Scanpy's pl.pca_variance_ratio() to explore.

# %% [markdown]
# ## Step 2: Run Hyperparameter Search

# %%
print("\nRunning hyperparameter search...")
print(f"  Configurations to test:")
print(f"    n_archetypes: {n_archetypes_range}")
print(f"    hidden_dims: {len(hidden_dims_options)} options")
print(f"    inflation_factor: {inflation_factor_range}")
print(f"  Total combinations: {len(n_archetypes_range) * len(hidden_dims_options) * len(inflation_factor_range)}")
print(f"  CV folds: {cv_folds}")
print(f"  This may take several minutes...")

cv_summary = pc.tl.hyperparameter_search(
    adata,
    n_archetypes_range=n_archetypes_range,
    hidden_dims_options=hidden_dims_options,
    inflation_factor_range=inflation_factor_range,
    cv_folds=cv_folds,
    max_epochs_cv=max_epochs_cv,
    early_stopping_patience=early_stopping_patience,
    speed_preset=speed_preset,
    subsample_fraction=subsample_fraction,
    max_cells_cv=max_cells_cv,
    random_state=random_state,
    device='cpu',  # Use 'cuda' if GPU available
)

print("  Hyperparameter search complete!")
# Out:
# Epoch 1/1
# Average loss: 4.2398
# Archetypal loss: 4.2398
# KLD loss: 30.8061
# Reconstruction loss: 4.2398
# Archetype R²: 0.3888
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 4.2398 (range: 4.2398 - 4.2398)
#   archetypal_loss: 4.2398 (range: 4.2398 - 4.2398)
#   archetype_r2: 0.3888 (range: 0.3888 - 0.3888)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9969, mean=0.1111
# Batch reconstruction MSE: 4.3782
# Archetype stats: min=-11.0884, max=18.2340
# Archetype change since last debug: 0.233413
# Archetype gradients: norm=0.023383, mean=0.000720
#
# Epoch 1/1
# Average loss: 4.1372
# Archetypal loss: 4.1372
# KLD loss: 24.3915
# Reconstruction loss: 4.1372
# Archetype R²: 0.4038
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 4.1372 (range: 4.1372 - 4.1372)
#   archetypal_loss: 4.1372 (range: 4.1372 - 4.1372)
#   archetype_r2: 0.4038 (range: 0.4038 - 0.4038)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9940, mean=0.1111
# Batch reconstruction MSE: 4.2507
# Archetype stats: min=-11.0978, max=18.2463
# Archetype change since last debug: 0.265236
# Archetype gradients: norm=0.014844, mean=0.000470
#
# Epoch 1/1
# Average loss: 4.0244
# Archetypal loss: 4.0244
# KLD loss: 24.2157
# Reconstruction loss: 4.0244
# Archetype R²: 0.4200
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 4.0244 (range: 4.0244 - 4.0244)
#   archetypal_loss: 4.0244 (range: 4.0244 - 4.0244)
#   archetype_r2: 0.4200 (range: 0.4200 - 0.4200)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9921, mean=0.1111
# Batch reconstruction MSE: 4.1260
# Archetype stats: min=-11.1028, max=18.2548
# Archetype change since last debug: 0.245826
# Archetype gradients: norm=0.014649, mean=0.000468
#
# Epoch 1/1
# Average loss: 3.9192
# Archetypal loss: 3.9192
# KLD loss: 23.8846
# Reconstruction loss: 3.9192
# Archetype R²: 0.4352
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.9192 (range: 3.9192 - 3.9192)
#   archetypal_loss: 3.9192 (range: 3.9192 - 3.9192)
#   archetype_r2: 0.4352 (range: 0.4352 - 0.4352)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9860, mean=0.1111
# Batch reconstruction MSE: 4.0537
# Archetype stats: min=-11.1087, max=18.2611
# Archetype change since last debug: 0.242501
# Archetype gradients: norm=0.013379, mean=0.000452
#
# Epoch 1/1
# Average loss: 3.8434
# Archetypal loss: 3.8434
# KLD loss: 23.6388
# Reconstruction loss: 3.8434
# Archetype R²: 0.4462
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.8434 (range: 3.8434 - 3.8434)
#   archetypal_loss: 3.8434 (range: 3.8434 - 3.8434)
#   archetype_r2: 0.4462 (range: 0.4462 - 0.4462)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9865, mean=0.1111
# Batch reconstruction MSE: 3.9756
# Archetype stats: min=-11.1145, max=18.2673
# Archetype change since last debug: 0.241747
# Archetype gradients: norm=0.012594, mean=0.000432
#
# Epoch 1/1
# Average loss: 3.7704
# Archetypal loss: 3.7704
# KLD loss: 23.4441
# Reconstruction loss: 3.7704
# Archetype R²: 0.4567
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.7704 (range: 3.7704 - 3.7704)
#   archetypal_loss: 3.7704 (range: 3.7704 - 3.7704)
#   archetype_r2: 0.4567 (range: 0.4567 - 0.4567)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9778, mean=0.1111
# Batch reconstruction MSE: 3.8943
# Archetype stats: min=-11.1204, max=18.2723
# Archetype change since last debug: 0.261329
# Archetype gradients: norm=0.014191, mean=0.000498
#
# Epoch 1/1
# Average loss: 3.6987
# Archetypal loss: 3.6987
# KLD loss: 24.0449
# Reconstruction loss: 3.6987
# Archetype R²: 0.4671
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.6987 (range: 3.6987 - 3.6987)
#   archetypal_loss: 3.6987 (range: 3.6987 - 3.6987)
#   archetype_r2: 0.4671 (range: 0.4671 - 0.4671)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9684, mean=0.1111
# Batch reconstruction MSE: 3.7997
# Archetype stats: min=-11.1271, max=18.2777
# Archetype change since last debug: 0.320977
# Archetype gradients: norm=0.017090, mean=0.000552
#
# Epoch 1/1
# Average loss: 3.6218
# Archetypal loss: 3.6218
# KLD loss: 24.6714
# Reconstruction loss: 3.6218
# Archetype R²: 0.4783
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.6218 (range: 3.6218 - 3.6218)
#   archetypal_loss: 3.6218 (range: 3.6218 - 3.6218)
#   archetype_r2: 0.4783 (range: 0.4783 - 0.4783)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9477, mean=0.1111
# Batch reconstruction MSE: 3.6857
# Archetype stats: min=-11.1338, max=18.2830
# Archetype change since last debug: 0.365429
# Archetype gradients: norm=0.016642, mean=0.000591
#
# Epoch 1/1
# Average loss: 3.5427
# Archetypal loss: 3.5427
# KLD loss: 24.7802
# Reconstruction loss: 3.5427
# Archetype R²: 0.4898
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.5427 (range: 3.5427 - 3.5427)
#   archetypal_loss: 3.5427 (range: 3.5427 - 3.5427)
#   archetype_r2: 0.4898 (range: 0.4898 - 0.4898)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9474, mean=0.1111
# Batch reconstruction MSE: 3.5819
# Archetype stats: min=-11.1386, max=18.2884
# Archetype change since last debug: 0.347697
# Archetype gradients: norm=0.020579, mean=0.000670
#
# Epoch 1/1
# Average loss: 3.4583
# Archetypal loss: 3.4583
# KLD loss: 25.1376
# Reconstruction loss: 3.4583
# Archetype R²: 0.5020
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.4583 (range: 3.4583 - 3.4583)
#   archetypal_loss: 3.4583 (range: 3.4583 - 3.4583)
#   archetype_r2: 0.5020 (range: 0.5020 - 0.5020)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9347, mean=0.1111
# Batch reconstruction MSE: 3.5090
# Archetype stats: min=-11.1444, max=18.2923
# Archetype change since last debug: 0.278437
# Archetype gradients: norm=0.022686, mean=0.000771
#
# Epoch 1/1
# Average loss: 3.3906
# Archetypal loss: 3.3906
# KLD loss: 24.9105
# Reconstruction loss: 3.3906
# Archetype R²: 0.5118
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.3906 (range: 3.3906 - 3.3906)
#   archetypal_loss: 3.3906 (range: 3.3906 - 3.3906)
#   archetype_r2: 0.5118 (range: 0.5118 - 0.5118)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9498, mean=0.1111
# Batch reconstruction MSE: 3.4713
# Archetype stats: min=-11.1530, max=18.2963
# Archetype change since last debug: 0.237385
# Archetype gradients: norm=0.038929, mean=0.001159
#
# Epoch 1/1
# Average loss: 3.3388
# Archetypal loss: 3.3388
# KLD loss: 24.5536
# Reconstruction loss: 3.3388
# Archetype R²: 0.5193
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.3388 (range: 3.3388 - 3.3388)
#   archetypal_loss: 3.3388 (range: 3.3388 - 3.3388)
#   archetype_r2: 0.5193 (range: 0.5193 - 0.5193)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9198, mean=0.1111
# Batch reconstruction MSE: 3.4102
# Archetype stats: min=-11.1608, max=18.2987
# Archetype change since last debug: 0.209777
# Archetype gradients: norm=0.026410, mean=0.000802
#
# Epoch 1/1
# Average loss: 3.2886
# Archetypal loss: 3.2886
# KLD loss: 23.4985
# Reconstruction loss: 3.2886
# Archetype R²: 0.5265
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.2886 (range: 3.2886 - 3.2886)
#   archetypal_loss: 3.2886 (range: 3.2886 - 3.2886)
#   archetype_r2: 0.5265 (range: 0.5265 - 0.5265)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9277, mean=0.1111
# Batch reconstruction MSE: 3.3809
# Archetype stats: min=-11.1680, max=18.3012
# Archetype change since last debug: 0.185783
# Archetype gradients: norm=0.038208, mean=0.001099
#
# Epoch 1/1
# Average loss: 3.2600
# Archetypal loss: 3.2600
# KLD loss: 22.4737
# Reconstruction loss: 3.2600
# Archetype R²: 0.5306
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.2600 (range: 3.2600 - 3.2600)
#   archetypal_loss: 3.2600 (range: 3.2600 - 3.2600)
#   archetype_r2: 0.5306 (range: 0.5306 - 0.5306)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9074, mean=0.1111
# Batch reconstruction MSE: 3.3466
# Archetype stats: min=-11.1749, max=18.3035
# Archetype change since last debug: 0.158476
# Archetype gradients: norm=0.027184, mean=0.000912
#
# Epoch 1/1
# Average loss: 3.2277
# Archetypal loss: 3.2277
# KLD loss: 21.5768
# Reconstruction loss: 3.2277
# Archetype R²: 0.5353
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.2277 (range: 3.2277 - 3.2277)
#   archetypal_loss: 3.2277 (range: 3.2277 - 3.2277)
#   archetype_r2: 0.5353 (range: 0.5353 - 0.5353)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9040, mean=0.1111
# Batch reconstruction MSE: 3.3261
# Archetype stats: min=-11.1797, max=18.3053
# Archetype change since last debug: 0.137413
# Archetype gradients: norm=0.036064, mean=0.001036
#
# Epoch 1/1
# Average loss: 3.1986
# Archetypal loss: 3.1986
# KLD loss: 21.2793
# Reconstruction loss: 3.1986
# Archetype R²: 0.5395
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1986 (range: 3.1986 - 3.1986)
#   archetypal_loss: 3.1986 (range: 3.1986 - 3.1986)
#   archetype_r2: 0.5395 (range: 0.5395 - 0.5395)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8874, mean=0.1111
# Batch reconstruction MSE: 3.3021
# Archetype stats: min=-11.1841, max=18.3080
# Archetype change since last debug: 0.135588
# Archetype gradients: norm=0.021298, mean=0.000692
#
# Epoch 1/1
# Average loss: 3.1780
# Archetypal loss: 3.1780
# KLD loss: 20.5680
# Reconstruction loss: 3.1780
# Archetype R²: 0.5424
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1780 (range: 3.1780 - 3.1780)
#   archetypal_loss: 3.1780 (range: 3.1780 - 3.1780)
#   archetype_r2: 0.5424 (range: 0.5424 - 0.5424)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8703, mean=0.1111
# Batch reconstruction MSE: 3.2808
# Archetype stats: min=-11.1889, max=18.3104
# Archetype change since last debug: 0.131124
# Archetype gradients: norm=0.028975, mean=0.000857
#
# Epoch 1/1
# Average loss: 3.1631
# Archetypal loss: 3.1631
# KLD loss: 20.2212
# Reconstruction loss: 3.1631
# Archetype R²: 0.5445
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1631 (range: 3.1631 - 3.1631)
#   archetypal_loss: 3.1631 (range: 3.1631 - 3.1631)
#   archetype_r2: 0.5445 (range: 0.5445 - 0.5445)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8555, mean=0.1111
# Batch reconstruction MSE: 3.2618
# Archetype stats: min=-11.1926, max=18.3131
# Archetype change since last debug: 0.130516
# Archetype gradients: norm=0.012504, mean=0.000426
#
# Epoch 1/1
# Average loss: 3.1498
# Archetypal loss: 3.1498
# KLD loss: 19.5232
# Reconstruction loss: 3.1498
# Archetype R²: 0.5463
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1498 (range: 3.1498 - 3.1498)
#   archetypal_loss: 3.1498 (range: 3.1498 - 3.1498)
#   archetype_r2: 0.5463 (range: 0.5463 - 0.5463)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8475, mean=0.1111
# Batch reconstruction MSE: 3.2473
# Archetype stats: min=-11.1964, max=18.3156
# Archetype change since last debug: 0.132942
# Archetype gradients: norm=0.013209, mean=0.000472
#
# Epoch 1/1
# Average loss: 3.1364
# Archetypal loss: 3.1364
# KLD loss: 19.2565
# Reconstruction loss: 3.1364
# Archetype R²: 0.5482
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1364 (range: 3.1364 - 3.1364)
#   archetypal_loss: 3.1364 (range: 3.1364 - 3.1364)
#   archetype_r2: 0.5482 (range: 0.5482 - 0.5482)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8406, mean=0.1111
# Batch reconstruction MSE: 3.2405
# Archetype stats: min=-11.2015, max=18.3184
# Archetype change since last debug: 0.152499
# Archetype gradients: norm=0.019323, mean=0.000685
#
# Epoch 1/1
# Average loss: 3.1278
# Archetypal loss: 3.1278
# KLD loss: 18.6694
# Reconstruction loss: 3.1278
# Archetype R²: 0.5494
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1278 (range: 3.1278 - 3.1278)
#   archetypal_loss: 3.1278 (range: 3.1278 - 3.1278)
#   archetype_r2: 0.5494 (range: 0.5494 - 0.5494)
#
# fc_Y Learning Summary:
#      Fold 3/3
#        Model input_dim: 50 (auto-detected from data)
# Archetypes parameter registered: True
# Archetypes requires_grad: True
# Deep_AA (Deep Archetypal Analysis) initialized:
#   - Single-stage architecture (like Deep_2)
#   - Inflation factor: 1.5
#   - Direct archetypal coordinates (no bottleneck)
#
#  Consolidated Archetype Initialization
#    PCHA: True, Inflation: False (factor: 1.0)
#    Test inflation: False
# Running PCHA initialization...
#   Input shape: (128, 50)
#   Target archetypes: 9
# Running PCHA with 9 archetypes...
# Data shape for PCHA: (50, 128)
# PCHA Results:
#   Archetypes shape: (9, 50)
#   Archetype R²: 0.6442
#   SSE: 15001.7451
#   PCHA archetype R²: 0.6442
#   Archetype shape: (9, 50)
# [OK] Initialized 9 archetypes using PCHA
# [OK] Archetype initialization complete (success: True)
#        [OK] Archetype initialization complete (PCHA: True, Inflation: 1.0)
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0004, max=0.8761, mean=0.1111
# Batch reconstruction MSE: 6.6268
# Archetype stats: min=-9.9075, max=19.2898
# Archetype gradients: norm=0.020651, mean=0.000735
#
# Epoch 1/1
# Average loss: 6.5591
# Archetypal loss: 6.5591
# KLD loss: 2.1224
# Reconstruction loss: 6.5591
# Archetype R²: 0.0143
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 6.5591 (range: 6.5591 - 6.5591)
#   archetypal_loss: 6.5591 (range: 6.5591 - 6.5591)
#   archetype_r2: 0.0143 (range: 0.0143 - 0.0143)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9516, mean=0.1111
# Batch reconstruction MSE: 6.0994
# Archetype stats: min=-9.8934, max=19.2815
# Archetype change since last debug: 0.307619
# Archetype gradients: norm=0.012399, mean=0.000417
#
# Epoch 1/1
# Average loss: 5.7065
# Archetypal loss: 5.7065
# KLD loss: 27.9648
# Reconstruction loss: 5.7065
# Archetype R²: 0.1436
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 5.7065 (range: 5.7065 - 5.7065)
#   archetypal_loss: 5.7065 (range: 5.7065 - 5.7065)
#   archetype_r2: 0.1436 (range: 0.1436 - 0.1436)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9861, mean=0.1111
# Batch reconstruction MSE: 5.3187
# Archetype stats: min=-9.8935, max=19.3054
# Archetype change since last debug: 0.427812
# Archetype gradients: norm=0.026962, mean=0.000810
#
# Epoch 1/1
# Average loss: 4.6823
# Archetypal loss: 4.6823
# KLD loss: 57.8798
# Reconstruction loss: 4.6823
# Archetype R²: 0.2983
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 4.6823 (range: 4.6823 - 4.6823)
#   archetypal_loss: 4.6823 (range: 4.6823 - 4.6823)
#   archetype_r2: 0.2983 (range: 0.2983 - 0.2983)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9881, mean=0.1111
# Batch reconstruction MSE: 4.4492
# Archetype stats: min=-9.8927, max=19.3393
# Archetype change since last debug: 0.463286
# Archetype gradients: norm=0.037437, mean=0.001067
#
# Epoch 1/1
# Average loss: 4.0629
# Archetypal loss: 4.0629
# KLD loss: 52.6361
# Reconstruction loss: 4.0629
# Archetype R²: 0.3912
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 4.0629 (range: 4.0629 - 4.0629)
#   archetypal_loss: 4.0629 (range: 4.0629 - 4.0629)
#   archetype_r2: 0.3912 (range: 0.3912 - 0.3912)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9895, mean=0.1111
# Batch reconstruction MSE: 4.0459
# Archetype stats: min=-9.8919, max=19.3672
# Archetype change since last debug: 0.376825
# Archetype gradients: norm=0.024800, mean=0.000770
#
# Epoch 1/1
# Average loss: 3.7874
# Archetypal loss: 3.7874
# KLD loss: 37.1953
# Reconstruction loss: 3.7874
# Archetype R²: 0.4323
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.7874 (range: 3.7874 - 3.7874)
#   archetypal_loss: 3.7874 (range: 3.7874 - 3.7874)
#   archetype_r2: 0.4323 (range: 0.4323 - 0.4323)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0002, max=0.9813, mean=0.1111
# Batch reconstruction MSE: 3.8797
# Archetype stats: min=-9.8908, max=19.3832
# Archetype change since last debug: 0.263875
# Archetype gradients: norm=0.023562, mean=0.000764
#
# Epoch 1/1
# Average loss: 3.6485
# Archetypal loss: 3.6485
# KLD loss: 24.7033
# Reconstruction loss: 3.6485
# Archetype R²: 0.4530
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.6485 (range: 3.6485 - 3.6485)
#   archetypal_loss: 3.6485 (range: 3.6485 - 3.6485)
#   archetype_r2: 0.4530 (range: 0.4530 - 0.4530)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0003, max=0.9735, mean=0.1111
# Batch reconstruction MSE: 3.7504
# Archetype stats: min=-9.8910, max=19.3996
# Archetype change since last debug: 0.205874
# Archetype gradients: norm=0.021031, mean=0.000672
#
# Epoch 1/1
# Average loss: 3.5689
# Archetypal loss: 3.5689
# KLD loss: 18.7437
# Reconstruction loss: 3.5689
# Archetype R²: 0.4649
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.5689 (range: 3.5689 - 3.5689)
#   archetypal_loss: 3.5689 (range: 3.5689 - 3.5689)
#   archetype_r2: 0.4649 (range: 0.4649 - 0.4649)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0004, max=0.9620, mean=0.1111
# Batch reconstruction MSE: 3.6379
# Archetype stats: min=-9.8937, max=19.4155
# Archetype change since last debug: 0.202500
# Archetype gradients: norm=0.018864, mean=0.000601
#
# Epoch 1/1
# Average loss: 3.5144
# Archetypal loss: 3.5144
# KLD loss: 17.0642
# Reconstruction loss: 3.5144
# Archetype R²: 0.4730
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.5144 (range: 3.5144 - 3.5144)
#   archetypal_loss: 3.5144 (range: 3.5144 - 3.5144)
#   archetype_r2: 0.4730 (range: 0.4730 - 0.4730)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0005, max=0.9561, mean=0.1111
# Batch reconstruction MSE: 3.5325
# Archetype stats: min=-9.9007, max=19.4287
# Archetype change since last debug: 0.243794
# Archetype gradients: norm=0.014838, mean=0.000492
#
# Epoch 1/1
# Average loss: 3.4486
# Archetypal loss: 3.4486
# KLD loss: 17.3501
# Reconstruction loss: 3.4486
# Archetype R²: 0.4830
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.4486 (range: 3.4486 - 3.4486)
#   archetypal_loss: 3.4486 (range: 3.4486 - 3.4486)
#   archetype_r2: 0.4830 (range: 0.4830 - 0.4830)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0006, max=0.9429, mean=0.1111
# Batch reconstruction MSE: 3.4400
# Archetype stats: min=-9.9182, max=19.4414
# Archetype change since last debug: 0.379484
# Archetype gradients: norm=0.015271, mean=0.000550
#
# Epoch 1/1
# Average loss: 3.3371
# Archetypal loss: 3.3371
# KLD loss: 18.6953
# Reconstruction loss: 3.3371
# Archetype R²: 0.4998
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.3371 (range: 3.3371 - 3.3371)
#   archetypal_loss: 3.3371 (range: 3.3371 - 3.3371)
#   archetype_r2: 0.4998 (range: 0.4998 - 0.4998)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0002, max=0.9269, mean=0.1111
# Batch reconstruction MSE: 3.3196
# Archetype stats: min=-9.9547, max=19.4532
# Archetype change since last debug: 0.450291
# Archetype gradients: norm=0.013118, mean=0.000457
#
# Epoch 1/1
# Average loss: 3.2071
# Archetypal loss: 3.2071
# KLD loss: 18.7426
# Reconstruction loss: 3.2071
# Archetype R²: 0.5192
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.2071 (range: 3.2071 - 3.2071)
#   archetypal_loss: 3.2071 (range: 3.2071 - 3.2071)
#   archetype_r2: 0.5192 (range: 0.5192 - 0.5192)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9418, mean=0.1111
# Batch reconstruction MSE: 3.2055
# Archetype stats: min=-10.0048, max=19.4638
# Archetype change since last debug: 0.438664
# Archetype gradients: norm=0.017014, mean=0.000607
#
# Epoch 1/1
# Average loss: 3.1111
# Archetypal loss: 3.1111
# KLD loss: 18.1283
# Reconstruction loss: 3.1111
# Archetype R²: 0.5335
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.1111 (range: 3.1111 - 3.1111)
#   archetypal_loss: 3.1111 (range: 3.1111 - 3.1111)
#   archetype_r2: 0.5335 (range: 0.5335 - 0.5335)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0002, max=0.9557, mean=0.1111
# Batch reconstruction MSE: 3.1410
# Archetype stats: min=-10.0427, max=19.4727
# Archetype change since last debug: 0.356949
# Archetype gradients: norm=0.019787, mean=0.000623
#
# Epoch 1/1
# Average loss: 3.0538
# Archetypal loss: 3.0538
# KLD loss: 17.0805
# Reconstruction loss: 3.0538
# Archetype R²: 0.5421
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.0538 (range: 3.0538 - 3.0538)
#   archetypal_loss: 3.0538 (range: 3.0538 - 3.0538)
#   archetype_r2: 0.5421 (range: 0.5421 - 0.5421)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0003, max=0.9402, mean=0.1111
# Batch reconstruction MSE: 3.0956
# Archetype stats: min=-10.0641, max=19.4772
# Archetype change since last debug: 0.262693
# Archetype gradients: norm=0.031154, mean=0.000897
#
# Epoch 1/1
# Average loss: 3.0106
# Archetypal loss: 3.0106
# KLD loss: 16.3028
# Reconstruction loss: 3.0106
# Archetype R²: 0.5486
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 3.0106 (range: 3.0106 - 3.0106)
#   archetypal_loss: 3.0106 (range: 3.0106 - 3.0106)
#   archetype_r2: 0.5486 (range: 0.5486 - 0.5486)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0006, max=0.9014, mean=0.1111
# Batch reconstruction MSE: 3.0569
# Archetype stats: min=-10.0799, max=19.4850
# Archetype change since last debug: 0.194373
# Archetype gradients: norm=0.028156, mean=0.000821
#
# Epoch 1/1
# Average loss: 2.9848
# Archetypal loss: 2.9848
# KLD loss: 15.5704
# Reconstruction loss: 2.9848
# Archetype R²: 0.5525
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9848 (range: 2.9848 - 2.9848)
#   archetypal_loss: 2.9848 (range: 2.9848 - 2.9848)
#   archetype_r2: 0.5525 (range: 0.5525 - 0.5525)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0007, max=0.9198, mean=0.1111
# Batch reconstruction MSE: 2.9912
# Archetype stats: min=-10.0940, max=19.4867
# Archetype change since last debug: 0.161110
# Archetype gradients: norm=0.020371, mean=0.000654
#
# Epoch 1/1
# Average loss: 2.9501
# Archetypal loss: 2.9501
# KLD loss: 15.2946
# Reconstruction loss: 2.9501
# Archetype R²: 0.5577
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9501 (range: 2.9501 - 2.9501)
#   archetypal_loss: 2.9501 (range: 2.9501 - 2.9501)
#   archetype_r2: 0.5577 (range: 0.5577 - 0.5577)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0006, max=0.8797, mean=0.1111
# Batch reconstruction MSE: 2.9596
# Archetype stats: min=-10.1081, max=19.4914
# Archetype change since last debug: 0.132964
# Archetype gradients: norm=0.022219, mean=0.000666
#
# Epoch 1/1
# Average loss: 2.9306
# Archetypal loss: 2.9306
# KLD loss: 15.4917
# Reconstruction loss: 2.9306
# Archetype R²: 0.5606
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9306 (range: 2.9306 - 2.9306)
#   archetypal_loss: 2.9306 (range: 2.9306 - 2.9306)
#   archetype_r2: 0.5606 (range: 0.5606 - 0.5606)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0007, max=0.8515, mean=0.1111
# Batch reconstruction MSE: 2.9345
# Archetype stats: min=-10.1201, max=19.4940
# Archetype change since last debug: 0.130826
# Archetype gradients: norm=0.018983, mean=0.000612
#
# Epoch 1/1
# Average loss: 2.9132
# Archetypal loss: 2.9132
# KLD loss: 15.4724
# Reconstruction loss: 2.9132
# Archetype R²: 0.5632
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9132 (range: 2.9132 - 2.9132)
#   archetypal_loss: 2.9132 (range: 2.9132 - 2.9132)
#   archetype_r2: 0.5632 (range: 0.5632 - 0.5632)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0006, max=0.8533, mean=0.1111
# Batch reconstruction MSE: 2.9038
# Archetype stats: min=-10.1288, max=19.4967
# Archetype change since last debug: 0.121012
# Archetype gradients: norm=0.021675, mean=0.000736
#
# Epoch 1/1
# Average loss: 2.9039
# Archetypal loss: 2.9039
# KLD loss: 15.5931
# Reconstruction loss: 2.9039
# Archetype R²: 0.5646
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9039 (range: 2.9039 - 2.9039)
#   archetypal_loss: 2.9039 (range: 2.9039 - 2.9039)
#   archetype_r2: 0.5646 (range: 0.5646 - 0.5646)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0008, max=0.8239, mean=0.1111
# Batch reconstruction MSE: 2.8851
# Archetype stats: min=-10.1366, max=19.4985
# Archetype change since last debug: 0.123930
# Archetype gradients: norm=0.015709, mean=0.000524
#
# Epoch 1/1
# Average loss: 2.8965
# Archetypal loss: 2.8965
# KLD loss: 15.6015
# Reconstruction loss: 2.8965
# Archetype R²: 0.5656
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8965 (range: 2.8965 - 2.8965)
#   archetypal_loss: 2.8965 (range: 2.8965 - 2.8965)
#   archetype_r2: 0.5656 (range: 0.5656 - 0.5656)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0008, max=0.8321, mean=0.1111
# Batch reconstruction MSE: 2.8730
# Archetype stats: min=-10.1428, max=19.5002
# Archetype change since last debug: 0.121778
# Archetype gradients: norm=0.022066, mean=0.000803
#
# Epoch 1/1
# Average loss: 2.8927
# Archetypal loss: 2.8927
# KLD loss: 15.6339
# Reconstruction loss: 2.8927
# Archetype R²: 0.5662
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8927 (range: 2.8927 - 2.8927)
#   archetypal_loss: 2.8927 (range: 2.8927 - 2.8927)
#   archetype_r2: 0.5662 (range: 0.5662 - 0.5662)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0010, max=0.7972, mean=0.1111
# Batch reconstruction MSE: 2.8536
# Archetype stats: min=-10.1482, max=19.5024
# Archetype change since last debug: 0.139158
# Archetype gradients: norm=0.015040, mean=0.000525
#
# Epoch 1/1
# Average loss: 2.8774
# Archetypal loss: 2.8774
# KLD loss: 15.8733
# Reconstruction loss: 2.8774
# Archetype R²: 0.5686
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8774 (range: 2.8774 - 2.8774)
#   archetypal_loss: 2.8774 (range: 2.8774 - 2.8774)
#   archetype_r2: 0.5686 (range: 0.5686 - 0.5686)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0011, max=0.8185, mean=0.1111
# Batch reconstruction MSE: 2.8412
# Archetype stats: min=-10.1528, max=19.5039
# Archetype change since last debug: 0.148820
# Archetype gradients: norm=0.020240, mean=0.000702
#
# Epoch 1/1
# Average loss: 2.8679
# Archetypal loss: 2.8679
# KLD loss: 16.1649
# Reconstruction loss: 2.8679
# Archetype R²: 0.5701
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8679 (range: 2.8679 - 2.8679)
#   archetypal_loss: 2.8679 (range: 2.8679 - 2.8679)
#   archetype_r2: 0.5701 (range: 0.5701 - 0.5701)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0012, max=0.7738, mean=0.1111
# Batch reconstruction MSE: 2.8291
# Archetype stats: min=-10.1583, max=19.5063
# Archetype change since last debug: 0.168257
# Archetype gradients: norm=0.016624, mean=0.000566
#
# Epoch 1/1
# Average loss: 2.8595
# Archetypal loss: 2.8595
# KLD loss: 16.2562
# Reconstruction loss: 2.8595
# Archetype R²: 0.5714
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8595 (range: 2.8595 - 2.8595)
#   archetypal_loss: 2.8595 (range: 2.8595 - 2.8595)
#   archetype_r2: 0.5714 (range: 0.5714 - 0.5714)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0014, max=0.8128, mean=0.1111
# Batch reconstruction MSE: 2.8189
# Archetype stats: min=-10.1620, max=19.5080
# Archetype change since last debug: 0.183669
# Archetype gradients: norm=0.022141, mean=0.000723
#
# Epoch 1/1
# Average loss: 2.8498
# Archetypal loss: 2.8498
# KLD loss: 16.5041
# Reconstruction loss: 2.8498
# Archetype R²: 0.5728
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8498 (range: 2.8498 - 2.8498)
#   archetypal_loss: 2.8498 (range: 2.8498 - 2.8498)
#   archetype_r2: 0.5728 (range: 0.5728 - 0.5728)
#
# fc_Y Learning Summary:
#    [OK] Completed in 17.8s
#    [STATS] Mean archetype R²: 0.5460
#    [STATS] Mean validation R²: 0.5460
#
# 🧪 Configuration 6/12: {'n_archetypes': 9, 'hidden_dims': [64, 128], 'inflation_factor': 1.5, 'use_pcha_init': True, 'use_inflation': True}
#      Fold 1/3
#        Model input_dim: 50 (auto-detected from data)
# Archetypes parameter registered: True
# Archetypes requires_grad: True
# Deep_AA (Deep Archetypal Analysis) initialized:
#   - Single-stage architecture (like Deep_2)
#   - Inflation factor: 1.5
#   - Direct archetypal coordinates (no bottleneck)
#
#  Consolidated Archetype Initialization
#    PCHA: True, Inflation: True (factor: 1.5)
#    Test inflation: False
# Running PCHA initialization...
#   Input shape: (128, 50)
#   Target archetypes: 9
# Running PCHA with 9 archetypes...
# Data shape for PCHA: (50, 128)
# PCHA Results:
#   Archetypes shape: (9, 50)
#   Archetype R²: 0.5965
#   SSE: 17036.3250
#   PCHA archetype R²: 0.5965
#   Archetype shape: (9, 50)
# [OK] Initialized 9 archetypes using PCHA
#
#  Scalar Archetypal Inflation (factor: 1.50)
#    [OK] Inflation complete
#       [STATS] Positioning verification:
#          Data radius (max): 34.728
#          Data radius (mean): 17.482
#          Archetype distances: 18.006 to 44.474
#          Archetypes outside data: 2/9
#          Min archetype separation: 25.191
# [OK] Archetype initialization complete (success: True)
#        [OK] Archetype initialization complete (PCHA: True, Inflation: 1.5)
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0009, max=0.8522, mean=0.1111
# Batch reconstruction MSE: 7.2672
# Archetype stats: min=-19.2476, max=28.2489
# Archetype gradients: norm=0.027053, mean=0.000927
#
# Epoch 1/1
# Average loss: 6.8182
# Archetypal loss: 6.8182
# KLD loss: 2.1133
# Reconstruction loss: 6.8182
# Archetype R²: 0.0014
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 6.8182 (range: 6.8182 - 6.8182)
#   archetypal_loss: 6.8182 (range: 6.8182 - 6.8182)
#   archetype_r2: 0.0014 (range: 0.0014 - 0.0014)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.9859, mean=0.1111
# Batch reconstruction MSE: 6.5790
# Archetype stats: min=-19.2350, max=28.2363
# Archetype change since last debug: 0.274145
# Archetype gradients: norm=0.012801, mean=0.000411
#
# Epoch 1/1
# Average loss: 6.0304
# Archetypal loss: 6.0304
# KLD loss: 11.9114
# Reconstruction loss: 6.0304
# Archetype R²: 0.1171
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 6.0304 (range: 6.0304 - 6.0304)
#   archetypal_loss: 6.0304 (range: 6.0304 - 6.0304)
#   archetype_r2: 0.1171 (range: 0.1171 - 0.1171)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# ...
# Archetype R²: 0.5563
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.9644 (range: 2.9644 - 2.9644)
#   archetypal_loss: 2.9644 (range: 2.9644 - 2.9644)
#   archetype_r2: 0.5563 (range: 0.5563 - 0.5563)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9982, mean=0.0909
# Batch reconstruction MSE: 2.9370
# Archetype stats: min=-14.4952, max=24.4698
# Archetype change since last debug: 0.190980
# Archetype gradients: norm=0.022330, mean=0.000612
#
# Epoch 1/1
# Average loss: 2.8645
# Archetypal loss: 2.8645
# KLD loss: 34.1852
# Reconstruction loss: 2.8645
# Archetype R²: 0.5712
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.8645 (range: 2.8645 - 2.8645)
#   archetypal_loss: 2.8645 (range: 2.8645 - 2.8645)
#   archetype_r2: 0.5712 (range: 0.5712 - 0.5712)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9972, mean=0.0909
# Batch reconstruction MSE: 2.8483
# Archetype stats: min=-14.4985, max=24.4760
# Archetype change since last debug: 0.153103
# Archetype gradients: norm=0.023250, mean=0.000648
#
# Epoch 1/1
# Average loss: 2.7984
# Archetypal loss: 2.7984
# KLD loss: 34.7140
# Reconstruction loss: 2.7984
# Archetype R²: 0.5810
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.7984 (range: 2.7984 - 2.7984)
#   archetypal_loss: 2.7984 (range: 2.7984 - 2.7984)
#   archetype_r2: 0.5810 (range: 0.5810 - 0.5810)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9958, mean=0.0909
# Batch reconstruction MSE: 2.7738
# Archetype stats: min=-14.4987, max=24.4828
# Archetype change since last debug: 0.141252
# Archetype gradients: norm=0.017640, mean=0.000521
#
# Epoch 1/1
# Average loss: 2.7478
# Archetypal loss: 2.7478
# KLD loss: 33.2621
# Reconstruction loss: 2.7478
# Archetype R²: 0.5886
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.7478 (range: 2.7478 - 2.7478)
#   archetypal_loss: 2.7478 (range: 2.7478 - 2.7478)
#   archetype_r2: 0.5886 (range: 0.5886 - 0.5886)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9950, mean=0.0909
# Batch reconstruction MSE: 2.7546
# Archetype stats: min=-14.5009, max=24.4884
# Archetype change since last debug: 0.133732
# Archetype gradients: norm=0.024467, mean=0.000741
#
# Epoch 1/1
# Average loss: 2.7108
# Archetypal loss: 2.7108
# KLD loss: 33.3583
# Reconstruction loss: 2.7108
# Archetype R²: 0.5940
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.7108 (range: 2.7108 - 2.7108)
#   archetypal_loss: 2.7108 (range: 2.7108 - 2.7108)
#   archetype_r2: 0.5940 (range: 0.5940 - 0.5940)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9867, mean=0.0909
# Batch reconstruction MSE: 2.7625
# Archetype stats: min=-14.5021, max=24.4958
# Archetype change since last debug: 0.120318
# Archetype gradients: norm=0.028735, mean=0.000858
#
# Epoch 1/1
# Average loss: 2.6808
# Archetypal loss: 2.6808
# KLD loss: 32.8165
# Reconstruction loss: 2.6808
# Archetype R²: 0.5985
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.6808 (range: 2.6808 - 2.6808)
#   archetypal_loss: 2.6808 (range: 2.6808 - 2.6808)
#   archetype_r2: 0.5985 (range: 0.5985 - 0.5985)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9847, mean=0.0909
# Batch reconstruction MSE: 2.8226
# Archetype stats: min=-14.5040, max=24.5014
# Archetype change since last debug: 0.111272
# Archetype gradients: norm=0.043780, mean=0.001247
#
# Epoch 1/1
# Average loss: 2.6648
# Archetypal loss: 2.6648
# KLD loss: 32.0108
# Reconstruction loss: 2.6648
# Archetype R²: 0.6008
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.6648 (range: 2.6648 - 2.6648)
#   archetypal_loss: 2.6648 (range: 2.6648 - 2.6648)
#   archetype_r2: 0.6008 (range: 0.6008 - 0.6008)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9569, mean=0.0909
# Batch reconstruction MSE: 2.9079
# Archetype stats: min=-14.5044, max=24.5078
# Archetype change since last debug: 0.097042
# Archetype gradients: norm=0.066219, mean=0.001630
#
# Epoch 1/1
# Average loss: 2.6476
# Archetypal loss: 2.6476
# KLD loss: 32.4714
# Reconstruction loss: 2.6476
# Archetype R²: 0.6033
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.6476 (range: 2.6476 - 2.6476)
#   archetypal_loss: 2.6476 (range: 2.6476 - 2.6476)
#   archetype_r2: 0.6033 (range: 0.6033 - 0.6033)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9759, mean=0.0909
# Batch reconstruction MSE: 2.8902
# Archetype stats: min=-14.5059, max=24.5113
# Archetype change since last debug: 0.090025
# Archetype gradients: norm=0.056426, mean=0.001588
#
# Epoch 1/1
# Average loss: 2.6347
# Archetypal loss: 2.6347
# KLD loss: 31.1247
# Reconstruction loss: 2.6347
# Archetype R²: 0.6052
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.6347 (range: 2.6347 - 2.6347)
#   archetypal_loss: 2.6347 (range: 2.6347 - 2.6347)
#   archetype_r2: 0.6052 (range: 0.6052 - 0.6052)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9248, mean=0.0909
# Batch reconstruction MSE: 2.7267
# Archetype stats: min=-14.5044, max=24.5164
# Archetype change since last debug: 0.085922
# Archetype gradients: norm=0.051519, mean=0.001285
#
# Epoch 1/1
# Average loss: 2.6072
# Archetypal loss: 2.6072
# KLD loss: 31.3155
# Reconstruction loss: 2.6072
# Archetype R²: 0.6094
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.6072 (range: 2.6072 - 2.6072)
#   archetypal_loss: 2.6072 (range: 2.6072 - 2.6072)
#   archetype_r2: 0.6094 (range: 0.6094 - 0.6094)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9610, mean=0.0909
# Batch reconstruction MSE: 2.6290
# Archetype stats: min=-14.5051, max=24.5187
# Archetype change since last debug: 0.084603
# Archetype gradients: norm=0.027620, mean=0.000878
#
# Epoch 1/1
# Average loss: 2.5876
# Archetypal loss: 2.5876
# KLD loss: 31.3952
# Reconstruction loss: 2.5876
# Archetype R²: 0.6123
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5876 (range: 2.5876 - 2.5876)
#   archetypal_loss: 2.5876 (range: 2.5876 - 2.5876)
#   archetype_r2: 0.6123 (range: 0.6123 - 0.6123)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8977, mean=0.0909
# Batch reconstruction MSE: 2.5735
# Archetype stats: min=-14.5052, max=24.5216
# Archetype change since last debug: 0.070396
# Archetype gradients: norm=0.021966, mean=0.000625
#
# Epoch 1/1
# Average loss: 2.5642
# Archetypal loss: 2.5642
# KLD loss: 31.5808
# Reconstruction loss: 2.5642
# Archetype R²: 0.6158
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5642 (range: 2.5642 - 2.5642)
#   archetypal_loss: 2.5642 (range: 2.5642 - 2.5642)
#   archetype_r2: 0.6158 (range: 0.6158 - 0.6158)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9575, mean=0.0909
# Batch reconstruction MSE: 2.5546
# Archetype stats: min=-14.5056, max=24.5253
# Archetype change since last debug: 0.073362
# Archetype gradients: norm=0.015304, mean=0.000512
#
# Epoch 1/1
# Average loss: 2.5490
# Archetypal loss: 2.5490
# KLD loss: 32.1773
# Reconstruction loss: 2.5490
# Archetype R²: 0.6181
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5490 (range: 2.5490 - 2.5490)
#   archetypal_loss: 2.5490 (range: 2.5490 - 2.5490)
#   archetype_r2: 0.6181 (range: 0.6181 - 0.6181)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8598, mean=0.0909
# Batch reconstruction MSE: 2.5305
# Archetype stats: min=-14.5071, max=24.5282
# Archetype change since last debug: 0.065399
# Archetype gradients: norm=0.018057, mean=0.000479
#
# Epoch 1/1
# Average loss: 2.5363
# Archetypal loss: 2.5363
# KLD loss: 32.4907
# Reconstruction loss: 2.5363
# Archetype R²: 0.6199
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5363 (range: 2.5363 - 2.5363)
#   archetypal_loss: 2.5363 (range: 2.5363 - 2.5363)
#   archetype_r2: 0.6199 (range: 0.6199 - 0.6199)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.9153, mean=0.0909
# Batch reconstruction MSE: 2.5297
# Archetype stats: min=-14.5076, max=24.5312
# Archetype change since last debug: 0.067337
# Archetype gradients: norm=0.017157, mean=0.000532
#
# Epoch 1/1
# Average loss: 2.5319
# Archetypal loss: 2.5319
# KLD loss: 33.0287
# Reconstruction loss: 2.5319
# Archetype R²: 0.6206
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5319 (range: 2.5319 - 2.5319)
#   archetypal_loss: 2.5319 (range: 2.5319 - 2.5319)
#   archetype_r2: 0.6206 (range: 0.6206 - 0.6206)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8330, mean=0.0909
# Batch reconstruction MSE: 2.5213
# Archetype stats: min=-14.5091, max=24.5344
# Archetype change since last debug: 0.062569
# Archetype gradients: norm=0.019936, mean=0.000535
#
# Epoch 1/1
# Average loss: 2.5177
# Archetypal loss: 2.5177
# KLD loss: 32.9624
# Reconstruction loss: 2.5177
# Archetype R²: 0.6228
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5177 (range: 2.5177 - 2.5177)
#   archetypal_loss: 2.5177 (range: 2.5177 - 2.5177)
#   archetype_r2: 0.6228 (range: 0.6228 - 0.6228)
#
# fc_Y Learning Summary:
# Starting training for 1 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: False, Validating constraints: False
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0000, max=0.8618, mean=0.0909
# Batch reconstruction MSE: 2.5369
# Archetype stats: min=-14.5097, max=24.5371
# Archetype change since last debug: 0.063356
# Archetype gradients: norm=0.024486, mean=0.000657
#
# Epoch 1/1
# Average loss: 2.5101
# Archetypal loss: 2.5101
# KLD loss: 33.1768
# Reconstruction loss: 2.5101
# Archetype R²: 0.6239
# fc_Y grad norm: 0.000000
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#
# Final Performance:
#   loss: 2.5101 (range: 2.5101 - 2.5101)
#   archetypal_loss: 2.5101 (range: 2.5101 - 2.5101)
#   archetype_r2: 0.6239 (range: 0.6239 - 0.6239)
#
# fc_Y Learning Summary:
#    [OK] Completed in 24.7s
#    [STATS] Mean archetype R²: 0.6089
#    [STATS] Mean validation R²: 0.6089
#
#  Grid search completed!
#    Best configuration: 11 archetypes, [256, 128, 64] hidden dims, λ=1.5
#    Archetype R²: 0.6089
#   Hyperparameter search complete!

# %% [markdown]
# Parameters passed here are default, you can change these or other parameters (e.g., 'archetypal_loss') as needed.

# %% [markdown]
# ## Step 3: Analyze Results

# %%
print("\nAnalyzing results...")

# Access ranked configurations (best to worst)
ranked_configs = cv_summary.ranked_configs

print(f"\nTop 3 configurations:")
for i, config in enumerate(ranked_configs[:3], 1):
    print(f"\n  {i}. Configuration:")
    print(f"     Performance (R²): {config['metric_value']:.4f} ± {config['std_error']:.4f}")
    print(f"     Settings: {config['config_summary']}")
    # Access hyperparameters dict
    hparams = config['hyperparameters']
    print(f"     Details:")
    print(f"       - n_archetypes: {hparams['n_archetypes']}")
    print(f"       - hidden_dims: {hparams['hidden_dims']}")
    print(f"       - inflation_factor: {hparams['inflation_factor']}")

# Get best configuration
best_config = ranked_configs[0]
print(f"\nRecommended configuration:")
print(f"  n_archetypes = {best_config['hyperparameters']['n_archetypes']}")
print(f"  hidden_dims = {best_config['hyperparameters']['hidden_dims']}")
print(f"  inflation_factor = {best_config['hyperparameters']['inflation_factor']}")
print(f"  Expected R² = {best_config['metric_value']:.4f}")
# Out:
# Analyzing results...
#
# Top 3 configurations:
#
#   1. Configuration:
#      Performance (R²): 0.6089 ± 0.0057
#      Settings: 11 archetypes, [256, 128, 64] hidden dims, λ=1.5
#      Details:
#        - n_archetypes: 11
#        - hidden_dims: [256, 128, 64]
#        - inflation_factor: 1.5
#
#   2. Configuration:
#      Performance (R²): 0.6027 ± 0.0095
#      Settings: 11 archetypes, [128, 64] hidden dims, λ=1.5
#      Details:
#        - n_archetypes: 11
#        - hidden_dims: [128, 64]
#        - inflation_factor: 1.5
#
#   3. Configuration:
#      Performance (R²): 0.5921 ± 0.0013
#      Settings: 9 archetypes, [128, 64] hidden dims, λ=1.5
#      Details:
#        - n_archetypes: 9
#        - hidden_dims: [128, 64]
#        - inflation_factor: 1.5
#
# Recommended configuration:
#   n_archetypes = 11
#   hidden_dims = [256, 128, 64]
#   inflation_factor = 1.5
#   Expected R² = 0.6089

# %% [markdown]
# Using 'best_config = ranked_configs[0]' returns the config that delivers the highest $R^2$, this is a useful way to programmatically access the best config if you're running this analysis in a script (e.g., part of a Snakemake workflow), but you can also visually inspect it to select the best configuration for your dataset using the elbow_curve() method below.

# %% [markdown]
# ## Step 4: Visualize Results with Elbow Plot
#
# The `pc.pl.elbow_curve()` function creates an interactive visualization showing:
# - Performance metrics (R², RMSE) across different numbers of archetypes
# - Results for all tested hyperparameter combinations (hidden_dims, inflation_factor)
# - Error bars from cross-validation folds

# %%
print("\nGenerating elbow plot using pc.pl.elbow_curve()...")

# Use PEACH's built-in elbow curve visualization
# Shows multiple metrics across all hyperparameter configurations
fig = pc.pl.elbow_curve(
    cv_summary,
    metrics=["archetype_r2", "mean_val_rmse"],  # Show both R² and RMSE
)

# Display interactive plot
fig.show()

# Display the summary DataFrame to see all hyperparameters explored
print("\nFull hyperparameter search results:")
print(cv_summary.summary_df.to_string())
# Out:
# Generating elbow plot using pc.pl.elbow_curve()...
# Full hyperparameter search results:
#     n_archetypes     hidden_dims  inflation_factor  use_pcha_init  use_inflation  mean_convergence_epoch  mean_val_archetype_r2  mean_val_mae  mean_archetype_r2  mean_val_rmse  mean_early_stopped  std_convergence_epoch  std_val_archetype_r2  std_val_mae  std_archetype_r2  std_val_rmse  std_early_stopped  training_time  early_stopping_rate
# 0              7       [128, 64]               1.0           True          False                    25.0               0.523364      1.223734           0.523364       1.800805                 0.0                    0.0              0.006811     0.018873          0.006811      0.026436                0.0      14.967988                  0.0
# 1              7       [128, 64]               1.5           True           True                    25.0               0.525295      1.216038           0.525295       1.797145                 0.0                    0.0              0.002924     0.003426          0.002924      0.019772                0.0      14.652772                  0.0
# 2              7  [256, 128, 64]               1.0           True          False                    25.0               0.513390      1.233822           0.513390       1.819534                 0.0                    0.0              0.016819     0.027618          0.016819      0.047850                0.0      17.667443                  0.0
# 3              7  [256, 128, 64]               1.5           True           True                    25.0               0.526204      1.221582           0.526204       1.795450                 0.0                    0.0              0.004735     0.005992          0.004735      0.024167                0.0      17.644125                  0.0
# 4              9       [128, 64]               1.0           True          False                    25.0               0.545984      1.198935           0.545984       1.757194                 0.0                    0.0              0.012670     0.013127          0.012670      0.016610                0.0      17.817975                  0.0
# 5              9       [128, 64]               1.5           True           True                    25.0               0.592101      1.156319           0.592101       1.665881                 0.0                    0.0              0.001274     0.000567          0.001274      0.015886                0.0      17.814216                  0.0
# 6              9  [256, 128, 64]               1.0           True          False                    25.0               0.552910      1.202490           0.552910       1.743383                 0.0                    0.0              0.020284     0.017922          0.020284      0.030704                0.0      20.795003                  0.0
# 7              9  [256, 128, 64]               1.5           True           True                    25.0               0.577809      1.172580           0.577809       1.694558                 0.0                    0.0              0.011997     0.011833          0.011997      0.022728                0.0      20.965029                  0.0
# 8             11       [128, 64]               1.0           True          False                    25.0               0.575601      1.178364           0.575601       1.699096                 0.0                    0.0              0.006369     0.012037          0.006369      0.009075                0.0      21.915368                  0.0
# 9             11       [128, 64]               1.5           True           True                    25.0               0.602715      1.156228           0.602715       1.644016                 0.0                    0.0              0.009476     0.014831          0.009476      0.029191                0.0      22.049284                  0.0
# 10            11  [256, 128, 64]               1.0           True          False                    25.0               0.575154      1.175513           0.575154       1.698644                 0.0                    0.0              0.034274     0.037607          0.034274      0.065987                0.0      25.127929                  0.0
# 11            11  [256, 128, 64]               1.5           True           True                    25.0               0.608874      1.130446           0.608874       1.631127                 0.0                    0.0              0.005681     0.004980          0.005681      0.006469                0.0      24.669151                  0.0

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*70)
print("WORKFLOW 02 COMPLETE")
print("="*70)
print(f"Configurations tested: {len(ranked_configs)}")
print(f"Best performance: R² = {best_config['metric_value']:.4f}")
print(f"\nBest hyperparameters:")
print(f"  • n_archetypes: {best_config['hyperparameters']['n_archetypes']}")
print(f"  • hidden_dims: {best_config['hyperparameters']['hidden_dims']}")
print(f"  • inflation_factor: {best_config['hyperparameters']['inflation_factor']}")
print(f"\nKey outputs:")
print(f"  • cv_summary.ranked_configs - Ranked configurations")
print(f"  • cv_summary.summary_df - Full results DataFrame")
print(f"  • pc.pl.elbow_curve() - Interactive visualization")
print("\nNext workflow: WORKFLOW_03 (Model Training with best config)")
print("="*70)
# Out:
# ======================================================================
# WORKFLOW 02 COMPLETE
# ======================================================================
# Configurations tested: 12
# Best performance: R² = 0.6089
#
# Best hyperparameters:
#   • n_archetypes: 11
#   • hidden_dims: [256, 128, 64]
#   • inflation_factor: 1.5
#
# Key outputs:
#   • cv_summary.ranked_configs - Ranked configurations
#   • cv_summary.summary_df - Full results DataFrame
#   • pc.pl.elbow_curve() - Interactive visualization
#
# Next workflow: WORKFLOW_03 (Model Training with best config)
# ======================================================================
