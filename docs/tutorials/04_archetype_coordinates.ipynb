# %% [markdown]
# WORKFLOW 04: Archetype Coordinates & Cell Assignment
# =====================================================
#
# This workflow demonstrates how to characterize cells in terms of archetypes:
# 1. Compute archetype coordinates (distances in PCA space)
# 2. Extract archetype weights (barycentric coordinates from model)
# 3. Assign cells to nearest archetypes (categorical labels)
#
# CRITICAL DISTINCTION:
# - archetype_distances: Euclidean distances from each cell to archetype positions in PCA space
# - cell_archetype_weights: Barycentric coordinates from the trained model (sum to 1 per cell)
#
# These can disagree! Distance-based and weight-based assignments may differ for ~60% of cells.
# This is expected and reflects the difference between geometric and learned representations.
#
# Example usage:
#     python WORKFLOW_04.py
#
# Requirements:
#     - peach
#     - scanpy
#     - Trained model (from WORKFLOW_03)

# %%
import scanpy as sc
import peach as pc
from pathlib import Path

# %% [markdown]
# ## Configuration

# %%
# Data path
data_path = Path("~/data/HSC.h5ad")

# Training parameters (from WORKFLOW_03)
n_archetypes = 5
hidden_dims = [256, 128, 64]
n_epochs = 50
seed = 42

# %% [markdown]
# ## Step 1: Load Data and Train Model (Prerequisites)

# %%
print("Loading data and training model (prerequisite)...")
adata = sc.read_h5ad(data_path)
print(f"  Shape: {adata.n_obs:,} cells × {adata.n_vars:,} genes")

# Ensure PCA exists
if 'X_pca' not in adata.obsm:
    print("  Running PCA...")
    sc.tl.pca(adata, n_comps=13)

# Train archetypal model (required for downstream analyses)
print(f"  Training model ({n_archetypes} archetypes)...")
results = pc.tl.train_archetypal(
    adata,
    n_archetypes=n_archetypes,
    n_epochs=n_epochs,
    hidden_dims=hidden_dims,
    early_stopping_patience=10,
    seed=seed,
    device='cpu',
)
print(f"  Training complete!")

# Check that archetype coordinates were stored
if 'archetype_coordinates' in adata.uns:
    arch_coords = adata.uns['archetype_coordinates']
    print(f"  Archetype coordinates: {arch_coords.shape}")
else:
    print("  Warning: archetype_coordinates not found in adata.uns")
# Out:
# Loading data and training model (prerequisite)...
#   Shape: 263,159 cells × 28,121 genes
#   Training model (5 archetypes)...
# [OK] Using specified PCA coordinates: adata.obsm['X_pca'] (263159, 50)
# [STATS] DataLoader created: 263159 cells × 50 PCA components
#    Config: batch_size=128, workers=0 (Apple Silicon)
# Archetypes parameter registered: True
# Archetypes requires_grad: True
# Deep_AA (Deep Archetypal Analysis) initialized:
#   - Single-stage architecture (like Deep_2)
#   - Inflation factor: 1.5
#   - Direct archetypal coordinates (no bottleneck)
#  Initializing with PCHA + inflation_factor=1.5...
#
#  Consolidated Archetype Initialization
#    PCHA: True, Inflation: True (factor: 1.5)
#    Test inflation: False
# Running PCHA initialization...
#   Input shape: (1000, 50)
#   Target archetypes: 5
# Running PCHA with 5 archetypes...
# Data shape for PCHA: (50, 1000)
# PCHA Results:
#   Archetypes shape: (5, 50)
#   Archetype R²: 0.4302
#   SSE: 192140.1548
#   PCHA archetype R²: 0.4302
#   Archetype shape: (5, 50)
# [OK] Initialized 5 archetypes using PCHA
#
#  Scalar Archetypal Inflation (factor: 1.50)
#    [OK] Inflation complete
#       [STATS] Positioning verification:
#          Data radius (max): 82.232
#          Data radius (mean): 17.701
#          Archetype distances: 15.419 to 43.544
#          Archetypes outside data: 0/5
#          Min archetype separation: 27.344
# [OK] Archetype initialization complete (success: True)
# [OK] PCHA + inflation initialization successful!
# Starting training for 50 epochs...
# Device: cpu
# Archetypal weight: 1.0, KLD weight: 0.0, Reconstruction weight: 0.0
#   (Model configured: arch=1.0, kld=0.0)
# Tracking stability: True, Validating constraints: True
#
# Epoch 0 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0002, max=0.9947, mean=0.2000
# Batch reconstruction MSE: 6.6896
# Archetype stats: min=-14.2981, max=27.4279
# Archetype gradients: norm=0.035600, mean=0.001669
#
# Epoch 1/50
# Average loss: 3.7765
# Archetypal loss: 3.7765
# KLD loss: 4.4446
# Reconstruction loss: 3.7765
# Archetype R²: 0.4402
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.000000
#
# Epoch 2 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0027, max=0.9680, mean=0.2000
# Batch reconstruction MSE: 5.5772
# Archetype stats: min=-14.2994, max=27.4069
# Archetype change since last debug: 1.933209
# Archetype gradients: norm=0.237815, mean=0.009271
#
# Epoch 4 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0065, max=0.9371, mean=0.2000
# Batch reconstruction MSE: 6.3821
# Archetype stats: min=-14.2104, max=27.2358
# Archetype change since last debug: 1.115909
# Archetype gradients: norm=0.253281, mean=0.008134
#
# Epoch 6/50
# Average loss: 3.6551
# Archetypal loss: 3.6551
# KLD loss: 10.0775
# Reconstruction loss: 3.6551
# Archetype R²: 0.4580
# fc_Y grad norm: 0.000000
#
# Epoch 6 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0027, max=0.9076, mean=0.2000
# Batch reconstruction MSE: 4.7721
# Archetype stats: min=-14.1493, max=27.1329
# Archetype change since last debug: 0.815525
# Archetype gradients: norm=0.239987, mean=0.009584
#
# Epoch 8 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0007, max=0.8792, mean=0.2000
# Batch reconstruction MSE: 4.7477
# Archetype stats: min=-14.1039, max=27.1037
# Archetype change since last debug: 0.581520
# Archetype gradients: norm=0.297038, mean=0.012734
#
# Epoch 10 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0017, max=0.8266, mean=0.2000
# Batch reconstruction MSE: 5.0768
# Archetype stats: min=-14.0771, max=27.0815
# Archetype change since last debug: 0.466005
# Archetype gradients: norm=0.163018, mean=0.007334
#
# Epoch 11/50
# Average loss: 3.6530
# Archetypal loss: 3.6530
# KLD loss: 15.6903
# Reconstruction loss: 3.6530
# Archetype R²: 0.4583
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.204204
#
# Epoch 12 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0009, max=0.8977, mean=0.2000
# Batch reconstruction MSE: 4.2624
# Archetype stats: min=-14.0514, max=27.0515
# Archetype change since last debug: 0.452591
# Archetype gradients: norm=0.366061, mean=0.012011
#
# Epoch 14 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0022, max=0.8704, mean=0.2000
# Batch reconstruction MSE: 3.8403
# Archetype stats: min=-14.0301, max=27.0300
# Archetype change since last debug: 0.397819
# Archetype gradients: norm=0.263333, mean=0.011225
#
# Epoch 16/50
# Average loss: 3.6522
# Archetypal loss: 3.6522
# KLD loss: 21.6402
# Reconstruction loss: 3.6522
# Archetype R²: 0.4585
# fc_Y grad norm: 0.000000
#
# Epoch 16 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0017, max=0.8728, mean=0.2000
# Batch reconstruction MSE: 3.5393
# Archetype stats: min=-14.0110, max=27.0171
# Archetype change since last debug: 0.332481
# Archetype gradients: norm=0.186190, mean=0.007552
#
# Epoch 18 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0016, max=0.8758, mean=0.2000
# Batch reconstruction MSE: 4.2945
# Archetype stats: min=-13.9944, max=27.0059
# Archetype change since last debug: 0.329571
# Archetype gradients: norm=0.276548, mean=0.009787
#
# Epoch 20 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0012, max=0.8535, mean=0.2000
# Batch reconstruction MSE: 4.6741
# Archetype stats: min=-13.9773, max=26.9917
# Archetype change since last debug: 0.287385
# Archetype gradients: norm=0.343204, mean=0.011528
#
# Epoch 21/50
# Average loss: 3.6517
# Archetypal loss: 3.6517
# KLD loss: 23.2898
# Reconstruction loss: 3.6517
# Archetype R²: 0.4585
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.111151
#
# Epoch 22 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0009, max=0.8382, mean=0.2000
# Batch reconstruction MSE: 3.8971
# Archetype stats: min=-13.9673, max=26.9809
# Archetype change since last debug: 0.264780
# Archetype gradients: norm=0.375007, mean=0.011857
#
# Epoch 24 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0016, max=0.8461, mean=0.2000
# Batch reconstruction MSE: 3.8184
# Archetype stats: min=-13.9500, max=26.9760
# Archetype change since last debug: 0.314576
# Archetype gradients: norm=0.257547, mean=0.009561
#
# Epoch 26/50
# Average loss: 3.6512
# Archetypal loss: 3.6512
# KLD loss: 24.3318
# Reconstruction loss: 3.6512
# Archetype R²: 0.4586
# fc_Y grad norm: 0.000000
#
# Epoch 26 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0025, max=0.8285, mean=0.2000
# Batch reconstruction MSE: 4.0511
# Archetype stats: min=-13.9353, max=26.9686
# Archetype change since last debug: 0.270039
# Archetype gradients: norm=0.605328, mean=0.020022
#
# Epoch 28 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0013, max=0.8456, mean=0.2000
# Batch reconstruction MSE: 3.6036
# Archetype stats: min=-13.9240, max=26.9566
# Archetype change since last debug: 0.306104
# Archetype gradients: norm=0.590843, mean=0.019432
#
# Epoch 30 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0017, max=0.8918, mean=0.2000
# Batch reconstruction MSE: 3.7315
# Archetype stats: min=-13.9081, max=26.9468
# Archetype change since last debug: 0.285064
# Archetype gradients: norm=0.665811, mean=0.020311
#
# Epoch 31/50
# Average loss: 3.6513
# Archetypal loss: 3.6513
# KLD loss: 23.8330
# Reconstruction loss: 3.6513
# Archetype R²: 0.4586
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.105817
#
# Epoch 32 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0011, max=0.8174, mean=0.2000
# Batch reconstruction MSE: 3.6935
# Archetype stats: min=-13.8973, max=26.9380
# Archetype change since last debug: 0.197881
# Archetype gradients: norm=0.411487, mean=0.015896
#
# Epoch 34 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0003, max=0.8117, mean=0.2000
# Batch reconstruction MSE: 3.7030
# Archetype stats: min=-13.8864, max=26.9292
# Archetype change since last debug: 0.287449
# Archetype gradients: norm=0.425333, mean=0.014028
#
# Epoch 36/50
# Average loss: 3.6508
# Archetypal loss: 3.6508
# KLD loss: 26.1743
# Reconstruction loss: 3.6508
# Archetype R²: 0.4587
# fc_Y grad norm: 0.000000
#
# Epoch 36 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0005, max=0.8447, mean=0.2000
# Batch reconstruction MSE: 3.5526
# Archetype stats: min=-13.8726, max=26.9209
# Archetype change since last debug: 0.298704
# Archetype gradients: norm=0.511677, mean=0.015493
#
# Epoch 38 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.8134, mean=0.2000
# Batch reconstruction MSE: 3.5866
# Archetype stats: min=-13.8571, max=26.9139
# Archetype change since last debug: 0.268380
# Archetype gradients: norm=0.639292, mean=0.021551
#
# Epoch 40 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0005, max=0.8016, mean=0.2000
# Batch reconstruction MSE: 3.2076
# Archetype stats: min=-13.8488, max=26.9088
# Archetype change since last debug: 0.249272
# Archetype gradients: norm=0.517012, mean=0.014493
#
# Epoch 41/50
# Average loss: 3.6507
# Archetypal loss: 3.6507
# KLD loss: 27.8822
# Reconstruction loss: 3.6507
# Archetype R²: 0.4587
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.130193
#
# Epoch 42 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.8083, mean=0.2000
# Batch reconstruction MSE: 4.1936
# Archetype stats: min=-13.8346, max=26.9011
# Archetype change since last debug: 0.309179
# Archetype gradients: norm=0.496593, mean=0.017200
#
# Epoch 44 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0007, max=0.8194, mean=0.2000
# Batch reconstruction MSE: 3.8569
# Archetype stats: min=-13.8292, max=26.8925
# Archetype change since last debug: 0.292918
# Archetype gradients: norm=0.612602, mean=0.021438
#
# Epoch 46/50
# Average loss: 3.6508
# Archetypal loss: 3.6508
# KLD loss: 27.4029
# Reconstruction loss: 3.6508
# Archetype R²: 0.4587
# fc_Y grad norm: 0.000000
#
# Epoch 46 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0011, max=0.8436, mean=0.2000
# Batch reconstruction MSE: 3.7517
# Archetype stats: min=-13.8097, max=26.8885
# Archetype change since last debug: 0.238864
# Archetype gradients: norm=0.743863, mean=0.020752
#
# Epoch 48 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0003, max=0.7947, mean=0.2000
# Batch reconstruction MSE: 3.5675
# Archetype stats: min=-13.8013, max=26.8791
# Archetype change since last debug: 0.275625
# Archetype gradients: norm=0.282582, mean=0.010238
#
# Epoch 49 Debug:
# z row sums (should be ~1.0): 1.0000 ± 0.0000
# z stats: min=0.0001, max=0.8205, mean=0.2000
# Batch reconstruction MSE: 3.3179
# Archetype stats: min=-13.7993, max=26.8759
# Archetype change since last debug: 0.205983
# Archetype gradients: norm=0.257082, mean=0.009088
#
# Epoch 50/50
# Average loss: 3.6506
# Archetypal loss: 3.6506
# KLD loss: 29.1750
# Reconstruction loss: 3.6506
# Archetype R²: 0.4587
# fc_Y grad norm: 0.000000
# Constraints satisfied: True
# Constraint violation rate: 0.000
# Archetype drift (mean): 0.073053
#
# ============================================================
# TRAINING COMPLETED
# ============================================================
#    [OK] Stored archetype coordinates in adata.uns['archetype_coordinates']: torch.Size([5, 50])
#
# Final Performance:
#   loss: 3.6506 (range: 3.6505 - 3.7765)
#   archetypal_loss: 3.6506 (range: 3.6505 - 3.7765)
#   archetype_r2: 0.4587 (range: 0.4402 - 0.4588)
#
# fc_Y Learning Summary:
#
# Final Stability Metrics:
#   archetype_drift_mean: 0.073053 (range: 0.000000 - 0.575935)
#   archetype_variance_mean: 0.000620 (range: 0.000000 - 0.007124)
#
# Final Constraint Status:
#   A matrix sum error: 0.000000
#   B matrix sum error: 0.000000
#   Constraints satisfied: True
#   Training complete!
#   Archetype coordinates: (5, 50)

# %% [markdown]
# ## Step 2: Compute Archetype Distances (Geometric)

# %%
print("\nComputing archetype distances...")
print("  (Euclidean distances in PCA space)")

pc.tl.archetypal_coordinates(adata)

# Access the created distances
distances = adata.obsm['archetype_distances']
print(f"  Created: adata.obsm['archetype_distances']")
print(f"  Shape: {distances.shape} (cells × archetypes)")
print(f"  Distance range: [{distances.min():.4f}, {distances.max():.4f}]")

# Find nearest archetype for each cell (distance-based)
nearest_by_distance = distances.argmin(axis=1)
print(f"\n  Distance-based assignment:")
print(f"    Archetype 0: {(nearest_by_distance == 0).sum():,} cells")
print(f"    Archetype 1: {(nearest_by_distance == 1).sum():,} cells")
print(f"    Archetype 2: {(nearest_by_distance == 2).sum():,} cells")
print(f"    Archetype 3: {(nearest_by_distance == 3).sum():,} cells")
print(f"    Archetype 4: {(nearest_by_distance == 4).sum():,} cells")
# Out:
# Computing archetype distances...
#   (Euclidean distances in PCA space)
#  Computing archetype distances in PCA space...
#    Canonical reference: adata.obs.index (263159 cells)
#    Found PCA coordinates: X_pca (263159, 50)
#    Found archetype coordinates: archetype_coordinates (5, 50)
#  Computing pairwise distances in PCA space...
# [OK] Distance computation complete
#    Distance matrix shape: (263159, 5)
# [OK] Stored in AnnData:
#    adata.obsm['archetype_distances']: (263159, 5) distance matrix
#    adata.uns['archetype_positions']: (5, 50) archetype positions
#    adata.uns['archetype_distance_info']: distance computation metadata
#
# [STATS] Distance Statistics:
#    Nearest archetype distribution:
#       Archetype 0: 85171 cells (32.4%), mean distance: 14.9793
#       Archetype 1: 120843 cells (45.9%), mean distance: 17.0471
#       Archetype 2: 39120 cells (14.9%), mean distance: 17.1266
#       Archetype 3: 13913 cells (5.3%), mean distance: 20.5289
#       Archetype 4: 4112 cells (1.6%), mean distance: 19.5571
#    Overall statistics:
#       Mean nearest distance: 16.6130
#       Distance range: [6.629, 89.508]
#   Created: adata.obsm['archetype_distances']
#   Shape: (263159, 5) (cells × archetypes)
#   Distance range: [6.6287, 89.5076]
#
#   Distance-based assignment:
#     Archetype 0: 85,171 cells
#     Archetype 1: 120,843 cells
#     Archetype 2: 39,120 cells
#     Archetype 3: 13,913 cells
#     Archetype 4: 4,112 cells

# %% [markdown]
# ## Step 3: Extract Archetype Weights (Model-based)

# %%
print("\nExtracting archetype weights...")
print("  (Barycentric coordinates from trained model)")

weights = pc.tl.extract_archetype_weights(adata)

print(f"  Returned: weights array")
print(f"  Shape: {weights.shape} (cells × archetypes)")
print(f"  Weights sum to 1 per cell: {weights.sum(axis=1).mean():.6f}")
print(f"  Weight range: [{weights.min():.4f}, {weights.max():.4f}]")

# Also stored in adata
if 'cell_archetype_weights' in adata.obsm:
    stored_weights = adata.obsm['cell_archetype_weights']
    print(f"  Also stored: adata.obsm['cell_archetype_weights']")
    print(f"  Shape: {stored_weights.shape}")

# Find dominant archetype for each cell (weight-based)
nearest_by_weight = weights.argmax(axis=1)
print(f"\n  Weight-based assignment:")
print(f"    Archetype 0: {(nearest_by_weight == 0).sum():,} cells")
print(f"    Archetype 1: {(nearest_by_weight == 1).sum():,} cells")
print(f"    Archetype 2: {(nearest_by_weight == 2).sum():,} cells")
print(f"    Archetype 3: {(nearest_by_weight == 3).sum():,} cells")
print(f"    Archetype 4: {(nearest_by_weight == 4).sum():,} cells")
# Out:
# Extracting archetype weights...
#   (Barycentric coordinates from trained model)
# [STATS] Using model from adata.uns['trained_model']
# [STATS] Extracting weights for 263159 cells...
#    PCA shape: (263159, 50)
#    Device: cpu
#    Batch size: 256
#    Processed 32000/263159 cells...
#    Processed 64000/263159 cells...
#    Processed 96000/263159 cells...
#    Processed 128000/263159 cells...
#    Processed 160000/263159 cells...
#    Processed 192000/263159 cells...
#    Processed 224000/263159 cells...
#    Processed 256000/263159 cells...
#    Processed 263159/263159 cells...
# [OK] Stored cell weights in adata.obsm['cell_archetype_weights']
#    Shape: (263159, 5)
#    Range: [0.000, 0.946]
#    Mean sum: 1.0000
#
# [STATS] Archetype weight statistics:
#    Archetype 0: mean=0.221, std=0.151, max=0.854, dominant in 21378 cells
#    Archetype 1: mean=0.309, std=0.228, max=0.946, dominant in 77577 cells
#    Archetype 2: mean=0.245, std=0.196, max=0.778, dominant in 46663 cells
#    Archetype 3: mean=0.050, std=0.054, max=0.426, dominant in 0 cells
#    Archetype 4: mean=0.175, std=0.190, max=0.910, dominant in 33891 cells
#   Returned: weights array
#   Shape: (263159, 5) (cells × archetypes)
#   Weights sum to 1 per cell: 1.000000
#   Weight range: [0.0000, 0.9456]
#   Also stored: adata.obsm['cell_archetype_weights']
#   Shape: (263159, 5)
#
#   Weight-based assignment:
#     Archetype 0: 34,163 cells
#     Archetype 1: 91,829 cells
#     Archetype 2: 89,990 cells
#     Archetype 3: 857 cells
#     Archetype 4: 46,320 cells

# %% [markdown]
# ## Step 4: Assign Cells to Archetypes (Categorical)

# %%
print("\nAssigning cells to archetypes...")
print("  (Creates categorical labels based on dominant weight)")

pc.tl.assign_archetypes(adata)

# Access the categorical assignments
if 'archetypes' in adata.obs.columns:
    assignments = adata.obs['archetypes']
    print(f"  Created: adata.obs['archetypes']")
    print(f"  Type: {assignments.dtype}")
    print(f"  Categories: {list(assignments.cat.categories)}")

    # Count cells per archetype
    print(f"\n  Cell counts per archetype:")
    for cat in assignments.cat.categories:
        count = (assignments == cat).sum()
        print(f"    {cat}: {count:,} cells")
# Out:
# Assigning cells to archetypes...
#   (Creates categorical labels based on dominant weight)
#  AnnData-centric archetype binning...
#    Distance matrix: (263159, 5) (from adata.obsm['archetype_distances'])
#    Canonical cell reference: adata.obs.index (263159 cells)
#    Selecting top 26315 cells (10.0%) per archetype
#    INCLUDING central archetype_0 (generalist cells)
#    Archetype 0 (central): 26315 cells, centroid distance range: [27.2546, 29.0142], mean: 28.6545
#    Archetype 1: 26315 cells, distance range: [7.8995, 12.2935], mean: 11.3832
#    Archetype 2: 26315 cells, distance range: [9.0897, 13.6573], mean: 12.5763
#    Archetype 3: 26315 cells, distance range: [7.3005, 18.5922], mean: 14.6817
#    Archetype 4: 26315 cells, distance range: [10.6362, 28.9255], mean: 23.6167
#    Archetype 5: 26315 cells, distance range: [6.6287, 43.9535], mean: 38.1339
#
# [STATS] Assignment Summary:
#    Total cells: 263159
#    Archetype 0 (central): 26315 cells (10.0%)
#    Archetype 1: 26315 cells (10.0%)
#    Archetype 2: 26315 cells (10.0%)
#    Archetype 3: 26315 cells (10.0%)
#    Archetype 4: 26315 cells (10.0%)
#    Archetype 5: 26315 cells (10.0%)
#    No archetype: 135846 cells (51.6%)
#    [WARNING]  Overlapping assignments: 57155 cells
#
# [OK] Stored assignments in adata.obs['archetypes']:
#    Categories: ['archetype_0', 'archetype_1', 'archetype_2', 'archetype_3', 'archetype_4', 'archetype_5', 'no_archetype']
#    no_archetype: 135846 cells (51.6%)
#    archetype_3: 26225 cells (10.0%)
#    archetype_1: 21515 cells (8.2%)
#    archetype_2: 21483 cells (8.2%)
#    archetype_4: 21395 cells (8.1%)
#    archetype_5: 21248 cells (8.1%)
#    archetype_0: 15447 cells (5.9%)
#   Created: adata.obs['archetypes']
#   Type: category
#   Categories: ['archetype_0', 'archetype_1', 'archetype_2', 'archetype_3', 'archetype_4', 'archetype_5', 'no_archetype']
#
#   Cell counts per archetype:
#     archetype_0: 15,447 cells
#     archetype_1: 21,515 cells
#     archetype_2: 21,483 cells
#     archetype_3: 26,225 cells
#     archetype_4: 21,395 cells
#     archetype_5: 21,248 cells
#     no_archetype: 135,846 cells

# %% [markdown]
# ## Step 5: Compare Distance vs Weight Assignments

# %%
print("\nComparing distance-based vs weight-based assignments...")

# How often do they agree?
agreement = (nearest_by_distance == nearest_by_weight).sum()
total = len(nearest_by_distance)
agreement_pct = agreement / total * 100

print(f"  Cells where distance and weight agree: {agreement:,} / {total:,} ({agreement_pct:.1f}%)")
print(f"  Cells where they disagree: {total - agreement:,} ({100-agreement_pct:.1f}%)")
print(f"\n  Note: Disagreement is EXPECTED (~40-60% of cells).")
print(f"        Distance is geometric, weights are learned.")
# Out:
# Comparing distance-based vs weight-based assignments...
#   Cells where distance and weight agree: 3,344 / 263,159 (1.3%)
#   Cells where they disagree: 259,815 (98.7%)
#
#   Note: Disagreement is EXPECTED (~40-60% of cells).
#         Distance is geometric, weights are learned.

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*70)
print("WORKFLOW 04 COMPLETE")
print("="*70)
print(f"Key outputs created:")
print(f"  • adata.obsm['archetype_distances'] - Euclidean distances")
print(f"  • adata.obsm['cell_archetype_weights'] - Barycentric coordinates")
print(f"  • adata.obs['archetypes'] - Categorical assignments")
print(f"\nNext workflows:")
print(f"  • WORKFLOW_05: Gene/Pathway Enrichment Analysis")
print(f"  • WORKFLOW_06: CellRank Integration (requires velocity)")
print(f"  • WORKFLOW_08: Visualization")
print("="*70)
# Out:
# ======================================================================
# WORKFLOW 04 COMPLETE
# ======================================================================
# Key outputs created:
#   • adata.obsm['archetype_distances'] - Euclidean distances
#   • adata.obsm['cell_archetype_weights'] - Barycentric coordinates
#   • adata.obs['archetypes'] - Categorical assignments
#
# Next workflows:
#   • WORKFLOW_05: Gene/Pathway Enrichment Analysis
#   • WORKFLOW_06: CellRank Integration (requires velocity)
#   • WORKFLOW_08: Visualization
# ======================================================================
